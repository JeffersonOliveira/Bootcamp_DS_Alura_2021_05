# %% [markdown]
# #MODULO 01

# %%
#Biblioteca de Análise de Dados
import pandas as pd
#Bibliotecas de Criação de Visualizações Gráficas
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
#Bibliotecas de Apresentação de Informações no Google Colab
from google.colab import widgets, output

pd.options.display.float_format = "{:.2f}".format

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   RESET = '\033[0m'

# %% [markdown]
# ##Aula 01 - Essa aulas 1 está somente para rodar o Dataset
# ---

# %% [markdown]
# O objetivo desta aula é importar os dados e iniciar a análise exploratória dos dados afim de endenter melhor as informações desta base de dados.
#
# - Iremos analisar e manipular dados reais da área da saúde.
# Serão avaliados os gastos hospitalares de todo o Brasil a partir de uma base de dados obtida do site do governo brasileiro.
#
# *   PROCEDIMENTOS HOSPITALARES DO SUS - POR LOCAL DE INTERNAÇÃO - BRASIL:
#     *   Valor total por Ano/mês atendimento segundo Unidade da Federação
# Período: Jan/2008-Mar/2021
#
#
# [Acesso direto a base selecionada](http://www2.datasus.gov.br/DATASUS/index.php?area=0202&id=11633&VObj=http://tabnet.datasus.gov.br/cgi/deftohtm.exe?sih/cnv/qi) para realização a análise exploratória nos dados:

# %% [markdown]
# ###Preparação do Ambiente:
# ---

# %% [markdown]
# ###Importação das bibliotecas e Exploração inicial:
# ---

# %%
url_dados = 'https://github.com/JeffersonOliveira/Bootcamp_DS_Alura_2021_05/blob/fd7bb80fc7dcd3b461fad4d41ea2255c44d5cafc/Modulo_01-Python_pandas_para_analise_de_dados_reais/Datasets/A004945189_28_143_208_Estado_Ano_mes_atendimento_a_partir_de_2008.csv?raw=True'
data = pd.read_csv(url_dados,
                   encoding='ISO-8859-1', 
                   skiprows=3, 
                   sep=";",
                   skipfooter=12, 
                   engine="python", 
                   thousands=".", 
                   decimal=",")

# %% [markdown]
# ###Visualizando as primeiras e últimas colunas do dataset:
# ---

# %%
guias = widgets.TabBar(['Estrutura', 'Registros Iniciais','Registros Finais','Media dos Registros'], location='top')

with guias.output_to('Estrutura'):
    print(color.BOLD+color.UNDERLINE+color.DARKCYAN+'\nEstrutura da Base de Dados:\n'+color.RESET)
    print(data.info())
    print(color.BOLD+'\n Shape do Dataset lido: {}'.format(data.shape)+color.RESET)
    
with guias.output_to('Registros Iniciais'):
    display(data.head())
with guias.output_to('Registros Finais'):
    display(data.tail())

with guias.output_to('Media dos Registros'):
    display(data.mean())
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id6"></div>
# Estrutura da Base de Dados:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 287 entries, Unidade da Federação to Total
# dtypes: float64(165), object(122)
# memory usage: 60.7+ KB
# None
#
#  Shape do Dataset lido: (27, 287)
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2021/Fev    2021/Mar         Total
# 0          11 Rondônia        -        -  ...  6039419.59  4732441.04  996411254.68
# 1              12 Acre        -        -  ...  2272733.90  1137341.65  450048530.47
# 2          13 Amazonas        -        -  ... 13679358.06  6799060.80 1917247936.05
# 3           14 Roraima        -        -  ...  3044798.77  2381844.31  328876965.09
# 4              15 Pará        -        -  ... 23343222.94 13069564.31 4705309002.29
#
# [5 rows x 287 columns]
#      Unidade da Federação 1992/Mar  ...    2021/Mar          Total
# 22   43 Rio Grande do Sul        -  ... 37798832.80 12764391179.92
# 23  50 Mato Grosso do Sul        -  ...  4035989.77  2324525096.33
# 24         51 Mato Grosso        -  ...  8835890.09  2180119781.15
# 25               52 Goiás        -  ... 24867001.02  4973572261.43
# 26    53 Distrito Federal        -  ... 14731938.43  2592422853.56
#
# [5 rows x 287 columns]
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
data
# Out:
#       Unidade da Federação  1992/Mar  ...     2021/Mar          Total
# 0              11 Rondônia         -  ...   4732441.04   996411254.68
# 1                  12 Acre         -  ...   1137341.65   450048530.47
# 2              13 Amazonas         -  ...   6799060.80  1917247936.05
# 3               14 Roraima         -  ...   2381844.31   328876965.09
# 4                  15 Pará         -  ...  13069564.31  4705309002.29
# 5                 16 Amapá         -  ...    989155.40   309860092.59
# 6             17 Tocantins         -  ...    928756.84  1020028272.64
# 7              21 Maranhão         -  ...  17294509.11  3871069498.04
# 8                 22 Piauí         -  ...   9542151.53  2280888802.74
# 9                 23 Ceará         -  ...  17173151.55  6591836650.18
# 10  24 Rio Grande do Norte         -  ...   8733455.36  2660122027.15
# 11              25 Paraíba         -  ...  12517894.05  2614919044.63
# 12           26 Pernambuco         -  ...  39472738.81  8581189975.91
# 13              27 Alagoas         -  ...   8180887.21  2236415402.51
# 14              28 Sergipe         -  ...   3081081.42  1215853015.00
# 15                29 Bahia         -  ...  31314602.44  9791541570.52
# 16         31 Minas Gerais         -  ...  79780838.00 20418737536.66
# 17       32 Espírito Santo         -  ...  15606368.11  3405850698.58
# 18       33 Rio de Janeiro         -  ...  49149884.48 10337389922.09
# 19            35 São Paulo  40243.16  ... 177408317.71 41396408548.81
# 20               41 Paraná         -  ...  43480729.07 14681514706.67
# 21       42 Santa Catarina         -  ...  19375822.56  7835011163.40
# 22    43 Rio Grande do Sul         -  ...  37798832.80 12764391179.92
# 23   50 Mato Grosso do Sul         -  ...   4035989.77  2324525096.33
# 24          51 Mato Grosso         -  ...   8835890.09  2180119781.15
# 25                52 Goiás         -  ...  24867001.02  4973572261.43
# 26     53 Distrito Federal         -  ...  14731938.43  2592422853.56
#
# [27 rows x 287 columns]

# %% [markdown]
# Uma vez que já temos os dados formatados e analisados, iremos passar para próxima análise.
#
# Decidiu-se escolher a data de "Jan/2008" para análise os valores de gastos na área da saúde de cada Estado.

# %%
#data.info(null_counts=True, verbose=True) --> O data.info( foi ativado para saber qual era o ANO/MES que estava comprometido - se tratava de um objeto ao invés de ser um float64)

# %% [markdown]
# Visualizando problema a coluan/ linha que está com dados como objeto:

# %% [markdown]
# A Partir do dado acima nos chamou atenção a data de "2009/Set" uma vez que ele é o único objeto e deveria ser float64 como os demais.
# - No gráfico abaixo se vê que no index "1"
# ```
# periodo = str('2009/Set')
# data.sort_values(periodo, ascending=False).plot(x="Unidade da Federação", y=periodo, kind="bar", figsize=(10,7))
# ```

# %%
data.plot(x="Unidade da Federação", y="2008/Ago")

# %% [markdown]
# ### Análise do mês de Agosto de 2008:
# Decidiu-se durante a aula utilizar a data Ago/2008, iremos analisar esse período através de um gráfico com as informações de Unidade Federativa por valor gastos no período.
#
# Já no gráfico abaixo pocurei melhorar a apresentação das informações de forma a facilitar o entendimento:

# %%
ax = data.sort_values('2008/Ago', ascending=False).plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(16,7), grid=False)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.xaxis.set_label_text("Unidades da Federação (UF)", fontsize = "13",  weight=(700))
ax.yaxis.set_label_text("Gasto em R$", fontsize = "13", weight=(700))

plt.xticks(rotation=40, ha='right', fontsize="10")
plt.title("DATASUS: Gastos hospitalares em Agosto/2008 por Unidades da Ferederação (UF) no Brasil", fontsize="20",  weight=(700) )
plt.show()

# %% [markdown]
# Exibo aqui também a média de gastos hospitalares em Ago/2008 para todos os Estados:

# %%
data_media_2008_Ago = data['2008/Ago'].mean()
print("Média de Gastos em Ago/2008 R$ {:7,.2f}".format(data_media_2008_Ago))
# Out:
# Média de Gastos em Ago/2008 R$ 26,641,365.10

# %% [markdown]
# ###Desafio 01: Escolher um título mais descritivo, que passe a mensagem adequada ao gráfico de barras.
#   - Item já cumprido no gráfico anterior.

# %% [markdown]
# ###Desafio 02: Faça a mesma análise realizada em aula, porém para o mês mais recente:
#
#   - O mês mais recente do dataset é o de março/2021.
#
#   Iremos realizar a plotagem dos dados desse periodo para analisarmos o gráfico:

# %%
mes = '2021/Mar'
ax = data.sort_values(mes, ascending=False).plot(x="Unidade da Federação", y=mes, kind="bar", figsize=(16,7), grid=False)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.xaxis.set_label_text("Unidades da Federação (UF)", fontsize = "13",  weight=(700))
ax.yaxis.set_label_text("Gasto em R$", fontsize = "13", weight=(700))

plt.xticks(rotation=40, ha='right', fontsize="10")
plt.title("DATASUS: Gastos hospitalares em Março/2021 por Unidades da Ferederação (UF) no Brasil", fontsize="20",  weight=(700) )
plt.show()

# %% [markdown]
# ###O que aprendemos nesta aula?
#   - Como utilizar o Tabnet para buscar dados da saúde Brasileira;
#   - Como utilizar o google Colaboratory;
#   - Como ler um arquivo CSV com Pandas;
#   - Como ler um arquivo CSV com caracteres especiais do idioma português;
#   - Como ignorar o cabeçalho de um arquivo CSV;
#   - O que são DataFrame;
#   - Os desafios de ler um arquivo do mundo real;
#   - Como formatar a impressão dos dados de um DataFrame Pandas;
#   - Como plotar um gráfico com o Pandas;
#   - Como formatar a sua visualização;
#   - Como alterar os ticks do seu gráfico utilizando o Matplotlib.

# %% [markdown]
# ##Aula 02

# %% [markdown]
# Trazendo 2 Colunas do dataframe via pandas:

# %%
data[{'2008/Ago','2008/Set'}].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %% [markdown]
# A Função mean faz o calculo da média somente onde temos todos os valores preenchidos. Então se você quiser retirar os valores não válido ou NAN podemos utilizar essa função incluindo a fundação index

# %%
data.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
colunas_usaveis = data.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  '2020/Ago',
#  '2020/Set',
#  '2020/Out',
#  '2020/Nov',
#  '2020/Dez',
#  '2021/Jan',
#  '2021/Fev',
#  '2021/Mar',
#  'Total']

# %%
data[colunas_usaveis]
# Out:
#       Unidade da Federação   2007/Ago  ...     2021/Mar          Total
# 0              11 Rondônia    4209.37  ...   4732441.04   996411254.68
# 1                  12 Acre   10470.07  ...   1137341.65   450048530.47
# 2              13 Amazonas   35752.72  ...   6799060.80  1917247936.05
# 3               14 Roraima    4785.91  ...   2381844.31   328876965.09
# 4                  15 Pará  181159.29  ...  13069564.31  4705309002.29
# 5                 16 Amapá   33672.74  ...    989155.40   309860092.59
# 6             17 Tocantins    4113.76  ...    928756.84  1020028272.64
# 7              21 Maranhão  385330.18  ...  17294509.11  3871069498.04
# 8                 22 Piauí  220788.25  ...   9542151.53  2280888802.74
# 9                 23 Ceará  357904.65  ...  17173151.55  6591836650.18
# 10  24 Rio Grande do Norte  134605.36  ...   8733455.36  2660122027.15
# 11              25 Paraíba   97352.78  ...  12517894.05  2614919044.63
# 12           26 Pernambuco  400640.85  ...  39472738.81  8581189975.91
# 13              27 Alagoas  104243.75  ...   8180887.21  2236415402.51
# 14              28 Sergipe   27453.63  ...   3081081.42  1215853015.00
# 15                29 Bahia  135146.36  ...  31314602.44  9791541570.52
# 16         31 Minas Gerais  971394.37  ...  79780838.00 20418737536.66
# 17       32 Espírito Santo   57408.11  ...  15606368.11  3405850698.58
# 18       33 Rio de Janeiro  469469.34  ...  49149884.48 10337389922.09
# 19            35 São Paulo 1665349.90  ... 177408317.71 41396408548.81
# 20               41 Paraná  554800.22  ...  43480729.07 14681514706.67
# 21       42 Santa Catarina  693955.05  ...  19375822.56  7835011163.40
# 22    43 Rio Grande do Sul 1049252.33  ...  37798832.80 12764391179.92
# 23   50 Mato Grosso do Sul  199556.12  ...   4035989.77  2324525096.33
# 24          51 Mato Grosso   63562.50  ...   8835890.09  2180119781.15
# 25                52 Goiás  179395.82  ...  24867001.02  4973572261.43
# 26     53 Distrito Federal  191951.47  ...  14731938.43  2592422853.56
#
# [27 rows x 166 columns]

# %%
#Comparando os Shapes das colunas totais e usáveis:
dados_de_shape = data.shape
print(dados_de_shape)
print(data[colunas_usaveis].shape)
# Out:
# (27, 287)
# (27, 166)

# %% [markdown]
# Com o resultado acima percebemos tinhamos 287 colunas e agora verificamos que só temos 165 colunas usáveis devia a presença de valores não númericos NAN.
#
# Como o index é imutável e precisaremos incluir atrás do insert a unidade da federação no novo dataframe "colunas_usaveis" precisaremos colocar os valores de index para dentro de uma lista de Python, segue como fazer:

# %%
usaveis = data[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2021/Mar         Total
# 0          11 Rondônia   4209.37  ...  4732441.04  996411254.68
# 1              12 Acre  10470.07  ...  1137341.65  450048530.47
# 2          13 Amazonas  35752.72  ...  6799060.80 1917247936.05
# 3           14 Roraima   4785.91  ...  2381844.31  328876965.09
# 4              15 Pará 181159.29  ... 13069564.31 4705309002.29
#
# [5 rows x 166 columns]

# %%
data.set_index("Unidade da Federação") # Utilizando set_index() dentro do dataframe original
# Out:
#                         1992/Mar  1992/Abr  ...     2021/Mar          Total
# Unidade da Federação                        ...
# 11 Rondônia                    -         -  ...   4732441.04   996411254.68
# 12 Acre                        -         -  ...   1137341.65   450048530.47
# 13 Amazonas                    -         -  ...   6799060.80  1917247936.05
# 14 Roraima                     -         -  ...   2381844.31   328876965.09
# 15 Pará                        -         -  ...  13069564.31  4705309002.29
# 16 Amapá                       -         -  ...    989155.40   309860092.59
# 17 Tocantins                   -         -  ...    928756.84  1020028272.64
# 21 Maranhão                    -         -  ...  17294509.11  3871069498.04
# 22 Piauí                       -         -  ...   9542151.53  2280888802.74
# 23 Ceará                       -         -  ...  17173151.55  6591836650.18
# 24 Rio Grande do Norte         -         -  ...   8733455.36  2660122027.15
# 25 Paraíba                     -         -  ...  12517894.05  2614919044.63
# 26 Pernambuco                  -         -  ...  39472738.81  8581189975.91
# 27 Alagoas                     -         -  ...   8180887.21  2236415402.51
# 28 Sergipe                     -         -  ...   3081081.42  1215853015.00
# 29 Bahia                       -         -  ...  31314602.44  9791541570.52
# 31 Minas Gerais                -         -  ...  79780838.00 20418737536.66
# 32 Espírito Santo              -         -  ...  15606368.11  3405850698.58
# 33 Rio de Janeiro              -         -  ...  49149884.48 10337389922.09
# 35 São Paulo            40243.16  11449.99  ... 177408317.71 41396408548.81
# 41 Paraná                      -         -  ...  43480729.07 14681514706.67
# 42 Santa Catarina              -         -  ...  19375822.56  7835011163.40
# 43 Rio Grande do Sul           -         -  ...  37798832.80 12764391179.92
# 50 Mato Grosso do Sul          -         -  ...   4035989.77  2324525096.33
# 51 Mato Grosso                 -         -  ...   8835890.09  2180119781.15
# 52 Goiás                       -         -  ...  24867001.02  4973572261.43
# 53 Distrito Federal            -         -  ...  14731938.43  2592422853.56
#
# [27 rows x 286 columns]

# %%
usaveis = usaveis.set_index("Unidade da Federação") # Utilizando o "slice" que foi feito para manter somente as colunas que estavam preenchidas.
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2021/Mar          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   4732441.04   996411254.68
# 12 Acre                  10470.07   14001.71  ...   1137341.65   450048530.47
# 13 Amazonas              35752.72   45570.64  ...   6799060.80  1917247936.05
# 14 Roraima                4785.91   11858.63  ...   2381844.31   328876965.09
# 15 Pará                 181159.29  433414.74  ...  13069564.31  4705309002.29
# 16 Amapá                 33672.74  104822.98  ...    989155.40   309860092.59
# 17 Tocantins              4113.76   76633.06  ...    928756.84  1020028272.64
# 21 Maranhão             385330.18 1018352.93  ...  17294509.11  3871069498.04
# 22 Piauí                220788.25  353468.67  ...   9542151.53  2280888802.74
# 23 Ceará                357904.65  572356.18  ...  17173151.55  6591836650.18
# 24 Rio Grande do Norte  134605.36  272088.08  ...   8733455.36  2660122027.15
# 25 Paraíba               97352.78  368130.43  ...  12517894.05  2614919044.63
# 26 Pernambuco           400640.85 1088340.42  ...  39472738.81  8581189975.91
# 27 Alagoas              104243.75  174024.90  ...   8180887.21  2236415402.51
# 28 Sergipe               27453.63   78565.19  ...   3081081.42  1215853015.00
# 29 Bahia                135146.36  448349.75  ...  31314602.44  9791541570.52
# 31 Minas Gerais         971394.37 2861781.50  ...  79780838.00 20418737536.66
# 32 Espírito Santo        57408.11  284224.80  ...  15606368.11  3405850698.58
# 33 Rio de Janeiro       469469.34  921646.57  ...  49149884.48 10337389922.09
# 35 São Paulo           1665349.90 4434168.64  ... 177408317.71 41396408548.81
# 41 Paraná               554800.22 1431708.01  ...  43480729.07 14681514706.67
# 42 Santa Catarina       693955.05 1092964.12  ...  19375822.56  7835011163.40
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  37798832.80 12764391179.92
# 50 Mato Grosso do Sul   199556.12  573675.41  ...   4035989.77  2324525096.33
# 51 Mato Grosso           63562.50  232444.62  ...   8835890.09  2180119781.15
# 52 Goiás                179395.82  418053.58  ...  24867001.02  4973572261.43
# 53 Distrito Federal     191951.47  769966.25  ...  14731938.43  2592422853.56
#
# [27 rows x 165 columns]

# %%
usaveis['2019/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc['12 Acre']
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Dez     3711660.71
# 2021/Jan     3005561.16
# 2021/Fev     2272733.90
# 2021/Mar     1137341.65
# Total      450048530.47
# Name: 12 Acre, Length: 165, dtype: float64

# %%
usaveis.plot(figsize=(12,6))  # plotando os valores

# %%
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Mar         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  4732441.04  996411254.68
# 12 Acre               10470.07  14001.71  ...  1137341.65  450048530.47
# 13 Amazonas           35752.72  45570.64  ...  6799060.80 1917247936.05
# 14 Roraima             4785.91  11858.63  ...  2381844.31  328876965.09
# 15 Pará              181159.29 433414.74  ... 13069564.31 4705309002.29
#
# [5 rows x 165 columns]

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
usaveis.T.plot(figsize=(10,6))

# %%
usaveis.T.tail()
# Out:
# Unidade da Federação  11 Rondônia  ...  53 Distrito Federal
# 2020/Dez               9003402.23  ...          22552034.04
# 2021/Jan               8414690.60  ...          22573869.50
# 2021/Fev               6039419.59  ...          19004029.87
# 2021/Mar               4732441.04  ...          14731938.43
# Total                996411254.68  ...        2592422853.56
#
# [5 rows x 27 columns]

# %%
usaveis = usaveis.drop("Total", axis=1)
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2021/Fev     2021/Mar
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   6039419.59   4732441.04
# 12 Acre                  10470.07   14001.71  ...   2272733.90   1137341.65
# 13 Amazonas              35752.72   45570.64  ...  13679358.06   6799060.80
# 14 Roraima                4785.91   11858.63  ...   3044798.77   2381844.31
# 15 Pará                 181159.29  433414.74  ...  23343222.94  13069564.31
# 16 Amapá                 33672.74  104822.98  ...   1534733.18    989155.40
# 17 Tocantins              4113.76   76633.06  ...    416534.32    928756.84
# 21 Maranhão             385330.18 1018352.93  ...  23260245.95  17294509.11
# 22 Piauí                220788.25  353468.67  ...  13636005.36   9542151.53
# 23 Ceará                357904.65  572356.18  ...  30186951.00  17173151.55
# 24 Rio Grande do Norte  134605.36  272088.08  ...  18186942.80   8733455.36
# 25 Paraíba               97352.78  368130.43  ...  16996494.03  12517894.05
# 26 Pernambuco           400640.85 1088340.42  ...  62259409.32  39472738.81
# 27 Alagoas              104243.75  174024.90  ...  12792571.64   8180887.21
# 28 Sergipe               27453.63   78565.19  ...   4129845.36   3081081.42
# 29 Bahia                135146.36  448349.75  ...  55544579.04  31314602.44
# 31 Minas Gerais         971394.37 2861781.50  ... 119877417.15  79780838.00
# 32 Espírito Santo        57408.11  284224.80  ...  25669612.63  15606368.11
# 33 Rio de Janeiro       469469.34  921646.57  ...  60873103.08  49149884.48
# 35 São Paulo           1665349.90 4434168.64  ... 268193064.06 177408317.71
# 41 Paraná               554800.22 1431708.01  ...  83130175.37  43480729.07
# 42 Santa Catarina       693955.05 1092964.12  ...  47429335.91  19375822.56
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  84404640.00  37798832.80
# 50 Mato Grosso do Sul   199556.12  573675.41  ...  11428462.42   4035989.77
# 51 Mato Grosso           63562.50  232444.62  ...  13207979.82   8835890.09
# 52 Goiás                179395.82  418053.58  ...  32253788.65  24867001.02
# 53 Distrito Federal     191951.47  769966.25  ...  19004029.87  14731938.43
#
# [27 rows x 164 columns]

# %%
ax = usaveis.T.plot(figsize=(16,8))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# Desafio 01: Reposicionar a legenda do gráfico em uma posição mais adequada - ok
#
# Desafio 02: Plotar o gráfico de linha com apenas 5 estados de sua preferência - ok

# %%
ax = usaveis.head().T.plot(figsize=(16,8))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
#mes = '2021/Mar'
#ax = data.sort_values(mes, ascending=False).plot(x="Unidade da Federação", y=mes, kind="bar", figsize=(16,7), grid=False)
#ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
#ax.xaxis.set_label_text("Unidades da Federação (UF)", fontsize = "13",  weight=(700))
#ax.yaxis.set_label_text("Gasto em R$", fontsize = "13", weight=(700))

#plt.xticks(rotation=40, ha='right', fontsize="10")


ax = usaveis.head().T.plot(figsize=(16,8))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.xaxis.set_label_text("Mês e Ano", fontsize="13", weight=(700))
ax.yaxis.set_label_text("Gastos em R$", fontsize="13", weight=(700))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("DATASUS: Gastos hospitalares de 5 Estados ao longo dos anos no Brasil", fontsize="20",  weight=(700) )
plt.show()

# %% [markdown]
# ##Aula 03

# %% [markdown]
# ##Aula 04

# %% [markdown]
# ##Aula 05
